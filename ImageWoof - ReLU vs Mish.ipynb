# %% [markdown]
# ## Adam + OneCycle + Mish

# %%
#mish
# %run train.py --run 10 --woof 1 --size 128 --bs 64 --mixup 0 --sa 0 --epoch 5 --lr 3e-3 --gpu 0 \
                --opt adam
# Out:
# lr: 0.003; eff_lr: 0.003; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /root/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.035491</td>
#       <td>2.668787</td>
#       <td>0.240000</td>
#       <td>0.736000</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.841882</td>
#       <td>1.930425</td>
#       <td>0.324000</td>
#       <td>0.848000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.624668</td>
#       <td>1.634601</td>
#       <td>0.522000</td>
#       <td>0.880000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.425097</td>
#       <td>1.410918</td>
# ...

# %%
#mish
# %run train.py --run 3 --woof 1 --size 128 --bs 64 --sa 0 --epoch 80  --gpu 0 \
                --opt adam --lr 1e-2 --mixup 0.2
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /root/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.147543</td>
#       <td>2.058335</td>
#       <td>0.306000</td>
#       <td>0.796000</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.000345</td>
#       <td>2.097902</td>
#       <td>0.340000</td>
#       <td>0.848000</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.881352</td>
#       <td>1.915642</td>
#       <td>0.412000</td>
#       <td>0.868000</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.828222</td>
#       <td>1.773402</td>
# ...

# %% [markdown]
# ## Adam + OneCycle + ReLU

# %%
#ReLU
# %run train.py --run 3 --woof 1 --size 128 --bs 64 --sa 0 --epoch 80  --gpu 0 \
                --opt adam --lr 1e-2 --mixup 0.2
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /root/.fastai/data/imagewoof-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.159441</td>
#       <td>2.076079</td>
#       <td>0.302000</td>
#       <td>0.756000</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.017155</td>
#       <td>1.982562</td>
#       <td>0.322000</td>
#       <td>0.822000</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.948011</td>
#       <td>2.008111</td>
#       <td>0.308000</td>
#       <td>0.846000</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.868186</td>
#       <td>1.985754</td>
# ...
