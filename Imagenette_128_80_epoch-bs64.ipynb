# %% [markdown]
# ## Baseline: Adam + OneCycle

# %% [markdown]
# ### lr = 1e-2

# %%
# %run train.py --run 2 --woof 0 --size 128 --bs 64 --mixup 0.2 --sa 0 --epoch 80 --lr 1e-2 --gpu 0 \
                --opt adam
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /root/.fastai/data/imagenette-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.738327</td>
#       <td>1.513733</td>
#       <td>0.614000</td>
#       <td>0.942000</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.571341</td>
#       <td>1.398484</td>
#       <td>0.652000</td>
#       <td>0.944000</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.511306</td>
#       <td>1.236106</td>
#       <td>0.738000</td>
#       <td>0.956000</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.465122</td>
#       <td>1.225523</td>
# ...

# %% [markdown]
# ## Over9000 (RAdam + LARS + LookAHead) + flat_and_anneal

# %%
# %run train.py --run 2 --woof 0 --size 128 --bs 64 --mixup 0.2 --sa 0 --epoch 80 --lr 1e-2 --gpu 0 \
                --opt over9000 --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.01; eff_lr: 0.01; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /root/.fastai/data/imagenette-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.852098</td>
#       <td>2.687975</td>
#       <td>0.394000</td>
#       <td>0.722000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.566690</td>
#       <td>1.229375</td>
#       <td>0.724000</td>
#       <td>0.968000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.430748</td>
#       <td>1.561038</td>
#       <td>0.584000</td>
#       <td>0.938000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.352981</td>
#       <td>1.000616</td>
# ...
