# %% [markdown]
# ## Baseline: Adam + OneCycle

# %% [markdown]
# ### lr = 3e-3

# %%
# %run train.py --run 5 --woof 0 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 20 --lr 3e-3 --gpu 0 \
                --opt adam
# Out:
# lr: 0.003; eff_lr: 0.003; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /root/.fastai/data/imagenette-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.609213</td>
#       <td>1.516991</td>
#       <td>0.616000</td>
#       <td>0.924000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.456962</td>
#       <td>1.735312</td>
#       <td>0.554000</td>
#       <td>0.938000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.372521</td>
#       <td>1.676279</td>
#       <td>0.520000</td>
#       <td>0.940000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.291462</td>
#       <td>3.059203</td>
# ...

# %% [markdown]
# ## Novograd + bigger lr

# %%
# %run train.py --run 5 --woof 0 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 20 --lr 3e-2 --gpu 0 \
                --opt novograd --sched_type flat_and_anneal --ann_start 0.5
# Out:
# lr: 0.03; eff_lr: 0.03; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /root/.fastai/data/imagenette-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.592413</td>
#       <td>1.635581</td>
#       <td>0.536000</td>
#       <td>0.902000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.373088</td>
#       <td>1.191483</td>
#       <td>0.730000</td>
#       <td>0.962000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.241084</td>
#       <td>1.392806</td>
#       <td>0.632000</td>
#       <td>0.948000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.158756</td>
#       <td>1.485478</td>
# ...

# %%
# %run train.py --run 5 --woof 0 --size 128 --bs 128 --mixup 0 --sa 0 --epoch 20 --lr 3e-2 --gpu 0 \
                --opt novograd
# Out:
# lr: 0.03; eff_lr: 0.03; size: 128; alpha: 0.99; mom: 0.9; eps: 1e-06
# /root/.fastai/data/imagenette-160
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.682800</td>
#       <td>2.148922</td>
#       <td>0.402000</td>
#       <td>0.852000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.427543</td>
#       <td>2.173695</td>
#       <td>0.358000</td>
#       <td>0.884000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.295659</td>
#       <td>1.308781</td>
#       <td>0.654000</td>
#       <td>0.952000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.229576</td>
#       <td>1.599833</td>
# ...
